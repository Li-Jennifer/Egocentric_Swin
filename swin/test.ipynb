# %%
# %cd ../
# Out:
# /root/autodl-tmp/mmaction2

# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix

# 读取swin_tiny_result.pkl文件
with open('swin_tiny_result.pkl', 'rb') as f:
    swin_tiny_result = pickle.load(f)
    
print(swin_tiny_result)
# 
# 读取val.txt文件
with open('fpha_val.txt', 'r') as f:
    val_filenames = f.read().splitlines()

# 读取label的annotation文件
with open('action_annotation.txt', 'r') as f:
    label_annotation = f.read().splitlines()

# 根据val.txt文件中的文件名获取标签
# true_labels = [label_annotation[filename] for filename in val_filenames]

# 提取预测结果中的类别
# predicted_labels = [result['predicted_label'] for result in swin_tiny_result]

# # 创建混淆矩阵
# confusion_mat = confusion_matrix(true_labels, predicted_labels)

# # 将混淆矩阵转换为DataFrame，以便更好地展示
# confusion_df = pd.DataFrame(confusion_mat, columns=np.unique(true_labels), index=np.unique(true_labels))

# print(confusion_df)
# Out:
# [{'img_shape': (224, 224), 'pred_labels': {'item': tensor([7])}, 'pred_scores': {'item': tensor([1.2557e-05, 4.4741e-06, 1.6643e-07, 4.8156e-06, 5.5735e-07, 6.3952e-06,
#         1.3796e-03, 7.4659e-01, 2.5185e-01, 2.9043e-05, 8.9365e-07, 2.0932e-07,
#         4.4324e-05, 9.1463e-06, 1.5447e-06, 2.4592e-07, 3.7259e-06, 5.4706e-07,
#         1.1037e-06, 9.3860e-07, 2.7574e-07, 8.5683e-07, 9.2225e-07, 1.5946e-05,
#         4.0589e-08, 1.7650e-06, 8.5300e-07, 1.7824e-06, 2.4349e-06, 5.1323e-07,
#         1.3821e-06, 1.1450e-07, 2.4842e-07, 2.2738e-06, 1.9579e-05, 1.6741e-06,
#         5.0930e-06, 8.2186e-08, 3.2170e-06, 8.8800e-08, 4.1598e-06, 1.5575e-07,
#         3.3209e-07, 6.8003e-07, 1.3150e-07])}, 'gt_labels': {'item': tensor([7])}}, {'img_shape': (224, 224), 'pred_labels': {'item': tensor([22])}, 'pred_scores': {'item': tensor([1.5120e-06, 7.8186e-08, 1.8825e-07, 6.4601e-07, 1.9171e-08, 9.3760e-08,
#         1.3522e-07, 6.7642e-08, 7.7436e-08, 2.9081e-08, 5.0097e-07, 1.7219e-07,
# ...
