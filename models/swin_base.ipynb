# %%
# %cd ../mmaction2
# Out:
# /root/autodl-tmp/mmaction2

# %% [markdown]
# ## swin_fpha_base

# %%
# %%writefile ./configs/egocentric/swin_base.py

#dataset
dataset_type = 'VideoDataset'
data_root = 'data/video_fpha/train'
data_root_val = 'data/video_fpha/val'
ann_file_train = 'data/video_fpha/fpha_train.txt'
ann_file_val = 'data/video_fpha/fpha_val.txt'
ann_file_test = 'data/video_fpha/fpha_val.txt'
auto_scale_lr = dict(base_batch_size=64, enable=False)
num_classes = 45

#hook
default_hooks = dict(
    checkpoint=dict(
        interval=1, max_keep_ckpts=3, save_best='auto', type='CheckpointHook'),
    logger=dict(ignore_last=True, interval=500, type='LoggerHook'),
    param_scheduler=dict(type='ParamSchedulerHook'),
    runtime_info=dict(type='RuntimeInfoHook'),
    sampler_seed=dict(type='DistSamplerSeedHook'),
    sync_buffers=dict(type='SyncBuffersHook'),
    timer=dict(type='IterTimerHook'))
#env
default_scope = 'mmaction'
env_cfg = dict(
    cudnn_benchmark=False,
    dist_cfg=dict(backend='nccl'),
    mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
file_client_args = dict(io_backend='disk')
launcher = 'none'
load_from = './checkpoints/swin_base.pth'
log_level = 'INFO'
log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)

#model
model = dict(
    backbone=dict(
        arch='base',
        attn_drop_rate=0.0,
        drop_path_rate=0.3,
        drop_rate=0.0,
        mlp_ratio=4.0,
        patch_norm=True,
        patch_size=(
            2,
            4,
            4,
        ),
        pretrained=
        'https://download.openmmlab.com/mmaction/v1.0/recognition/swin/swin_base_patch4_window7_224.pth',
        pretrained2d=True,
        qk_scale=None,
        qkv_bias=True,
        type='SwinTransformer3D',
        window_size=(
            8,
            7,
            7,
        )),
    cls_head=dict(
        average_clips='prob',
        dropout_ratio=0.5,
        in_channels=1024,
        num_classes=45, #classes
        spatial_type='avg',
        type='I3DHead'),
    data_preprocessor=dict(
        format_shape='NCTHW',
        mean=[
            123.675,
            116.28,
            103.53,
        ],
        std=[
            58.395,
            57.12,
            57.375,
        ],
        type='ActionDataPreprocessor'),
    type='Recognizer3D')
#optim
optim_wrapper = dict(
    constructor='SwinOptimWrapperConstructor',
    optimizer=dict(
        betas=(
            0.9,
            0.999,
        ), lr=0.001, type='AdamW', weight_decay=0.05),
    paramwise_cfg=dict(
        absolute_pos_embed=dict(decay_mult=0.0),
        backbone=dict(lr_mult=0.1),
        norm=dict(decay_mult=0.0),
        relative_position_bias_table=dict(decay_mult=0.0)),
    type='AmpOptimWrapper')

#param
param_scheduler = [
    dict(
        begin=0,
        by_epoch=True,
        convert_to_iter_based=True,
        end=2.5,
        start_factor=0.1,
        type='LinearLR'),
    dict(
        T_max=30,
        begin=0,
        by_epoch=True,
        end=30,
        eta_min=0,
        type='CosineAnnealingLR'),
]
randomness = dict(deterministic=False, diff_rank_seed=False, seed=None)
resume = False
#test
test_cfg = dict(type='TestLoop')
test_dataloader = dict(
    batch_size=1,
    dataset=dict(
        ann_file='data/video_fpha/fpha_val.txt',
        data_prefix=dict(video='data/video_fpha/val'),
        pipeline=[
            dict(io_backend='disk', type='DecordInit'),
            dict(
                clip_len=32,
                frame_interval=2,
                num_clips=4,
                test_mode=True,
                type='SampleFrames'),
            dict(type='DecordDecode'),
            dict(scale=(
                -1,
                224,
            ), type='Resize'),
            dict(crop_size=224, type='ThreeCrop'),
            dict(input_format='NCTHW', type='FormatShape'),
            dict(type='PackActionInputs'),
        ],
        test_mode=True,
        type='VideoDataset'),
    num_workers=8,
    persistent_workers=True,
    sampler=dict(shuffle=False, type='DefaultSampler'))
test_evaluator = dict(type='AccMetric')
test_pipeline = [
    dict(io_backend='disk', type='DecordInit'),
    dict(
        clip_len=32,
        frame_interval=2,
        num_clips=4,
        test_mode=True,
        type='SampleFrames'),
    dict(type='DecordDecode'),
    dict(scale=(
        -1,
        224,
    ), type='Resize'),
    dict(crop_size=224, type='ThreeCrop'),
    dict(input_format='NCTHW', type='FormatShape'),
    dict(type='PackActionInputs'),
]
#train
train_cfg = dict( # max_epochs
    max_epochs=64, type='EpochBasedTrainLoop', val_begin=1, val_interval=1)
train_dataloader = dict(
    batch_size=2,
    dataset=dict(
        ann_file='data/video_fpha/fpha_train.txt',
        data_prefix=dict(video='data/video_fpha/train'),
        pipeline=[
            dict(io_backend='disk', type='DecordInit'),
            dict(
                clip_len=32,
                frame_interval=2,
                num_clips=1,
                type='SampleFrames'),
            dict(type='DecordDecode'),
            dict(scale=(
                -1,
                256,
            ), type='Resize'),
            dict(type='RandomResizedCrop'),
            dict(keep_ratio=False, scale=(
                224,
                224,
            ), type='Resize'),
            dict(flip_ratio=0.5, type='Flip'),
            dict(input_format='NCTHW', type='FormatShape'),
            dict(type='PackActionInputs'),
        ],
        type='VideoDataset'),
    num_workers=8,
    persistent_workers=True,
    sampler=dict(shuffle=True, type='DefaultSampler'))
train_pipeline = [
    dict(io_backend='disk', type='DecordInit'),
    dict(clip_len=32, frame_interval=2, num_clips=1, type='SampleFrames'),
    dict(type='DecordDecode'),
    dict(scale=(
        -1,
        256,
    ), type='Resize'),
    dict(type='RandomResizedCrop'),
    dict(keep_ratio=False, scale=(
        224,
        224,
    ), type='Resize'),
    dict(flip_ratio=0.5, type='Flip'),
    dict(input_format='NCTHW', type='FormatShape'),
    dict(type='PackActionInputs'),
]
#val
val_cfg = dict(type='ValLoop')
val_dataloader = dict(
    batch_size=2,
    dataset=dict(
        ann_file='data/video_fpha/fpha_val.txt',
        data_prefix=dict(video='data/video_fpha/val'),
        pipeline=[
            dict(io_backend='disk', type='DecordInit'),
            dict(
                clip_len=32,
                frame_interval=2,
                num_clips=1,
                test_mode=True,
                type='SampleFrames'),
            dict(type='DecordDecode'),
            dict(scale=(
                -1,
                256,
            ), type='Resize'),
            dict(crop_size=224, type='CenterCrop'),
            dict(input_format='NCTHW', type='FormatShape'),
            dict(type='PackActionInputs'),
        ],
        test_mode=True,
        type='VideoDataset'),
    num_workers=8,
    persistent_workers=True,
    sampler=dict(shuffle=False, type='DefaultSampler'))
val_evaluator = dict(type='AccMetric')
val_pipeline = [
    dict(io_backend='disk', type='DecordInit'),
    dict(
        clip_len=32,
        frame_interval=2,
        num_clips=1,
        test_mode=True,
        type='SampleFrames'),
    dict(type='DecordDecode'),
    dict(scale=(
        -1,
        256,
    ), type='Resize'),
    dict(crop_size=224, type='CenterCrop'),
    dict(input_format='NCTHW', type='FormatShape'),
    dict(type='PackActionInputs'),
]
vis_backends = [
    dict(type='LocalVisBackend'),
]
visualizer = dict(
    type='ActionVisualizer', vis_backends=[
        dict(type='LocalVisBackend'),
    ])
work_dir = './work_dirs/swin_base'
# Out:
# Overwriting ./configs/egocentric/swin_base.py

# %%
# !python tools/train.py ./configs/egocentric/swin_base.py
# Out:
# 08/29 09:09:26 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 921284795
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu118
#     OpenCV: 4.8.0
#     MMEngine: 0.8.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     deterministic: False
#     diff_rank_seed: False
#     seed: 921284795
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/29 09:09:26 - mmengine - INFO - Config:
# ann_file_test = 'data/video_fpha/fpha_val.txt'
# ann_file_train = 'data/video_fpha/fpha_train.txt'
# ann_file_val = 'data/video_fpha/fpha_val.txt'
# auto_scale_lr = dict(base_batch_size=64, enable=False)
# data_root = 'data/video_fpha/train'
# data_root_val = 'data/video_fpha/val'
# dataset_type = 'VideoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1, max_keep_ckpts=3, save_best='auto', type='CheckpointHook'),
#     logger=dict(ignore_last=True, interval=500, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     runtime_info=dict(type='RuntimeInfoHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffers=dict(type='SyncBuffersHook'),
#     timer=dict(type='IterTimerHook'))
# default_scope = 'mmaction'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# file_client_args = dict(io_backend='disk')
# launcher = 'none'
# load_from = './checkpoints/swin_base.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)
# model = dict(
#     backbone=dict(
#         arch='base',
#         attn_drop_rate=0.0,
#         drop_path_rate=0.3,
#         drop_rate=0.0,
#         mlp_ratio=4.0,
#         patch_norm=True,
#         patch_size=(
#             2,
#             4,
#             4,
#         ),
#         pretrained=
#         'https://download.openmmlab.com/mmaction/v1.0/recognition/swin/swin_base_patch4_window7_224.pth',
#         pretrained2d=True,
#         qk_scale=None,
#         qkv_bias=True,
#         type='SwinTransformer3D',
#         window_size=(
#             8,
#             7,
#             7,
#         )),
#     cls_head=dict(
#         average_clips='prob',
#         dropout_ratio=0.5,
#         in_channels=1024,
#         num_classes=45,
#         spatial_type='avg',
#         type='I3DHead'),
#     data_preprocessor=dict(
#         format_shape='NCTHW',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='ActionDataPreprocessor'),
#     type='Recognizer3D')
# num_classes = 45
# optim_wrapper = dict(
#     constructor='SwinOptimWrapperConstructor',
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=0.001, type='AdamW', weight_decay=0.05),
#     paramwise_cfg=dict(
#         absolute_pos_embed=dict(decay_mult=0.0),
#         backbone=dict(lr_mult=0.1),
#         norm=dict(decay_mult=0.0),
#         relative_position_bias_table=dict(decay_mult=0.0)),
#     type='AmpOptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=2.5,
#         start_factor=0.1,
#         type='LinearLR'),
#     dict(
#         T_max=30,
#         begin=0,
#         by_epoch=True,
#         end=30,
#         eta_min=0,
#         type='CosineAnnealingLR'),
# ]
# randomness = dict(deterministic=False, diff_rank_seed=False, seed=None)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_val.txt',
#         data_prefix=dict(video='data/video_fpha/val'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=4,
#                 test_mode=True,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 224,
#             ), type='Resize'),
#             dict(crop_size=224, type='ThreeCrop'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         test_mode=True,
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(type='AccMetric')
# test_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(
#         clip_len=32,
#         frame_interval=2,
#         num_clips=4,
#         test_mode=True,
#         type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         224,
#     ), type='Resize'),
#     dict(crop_size=224, type='ThreeCrop'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# train_cfg = dict(
#     max_epochs=64, type='EpochBasedTrainLoop', val_begin=1, val_interval=1)
# train_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_train.txt',
#         data_prefix=dict(video='data/video_fpha/train'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=1,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 256,
#             ), type='Resize'),
#             dict(type='RandomResizedCrop'),
#             dict(keep_ratio=False, scale=(
#                 224,
#                 224,
#             ), type='Resize'),
#             dict(flip_ratio=0.5, type='Flip'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(clip_len=32, frame_interval=2, num_clips=1, type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         256,
#     ), type='Resize'),
#     dict(type='RandomResizedCrop'),
#     dict(keep_ratio=False, scale=(
#         224,
#         224,
#     ), type='Resize'),
#     dict(flip_ratio=0.5, type='Flip'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_val.txt',
#         data_prefix=dict(video='data/video_fpha/val'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=1,
#                 test_mode=True,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 256,
#             ), type='Resize'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         test_mode=True,
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(type='AccMetric')
# val_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(
#         clip_len=32,
#         frame_interval=2,
#         num_clips=1,
#         test_mode=True,
#         type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         256,
#     ), type='Resize'),
#     dict(crop_size=224, type='CenterCrop'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='ActionVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/swin_base'
#
# /root/miniconda3/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 08/29 09:09:30 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/29 09:09:30 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.reduction.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.reduction.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.reduction.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.reduction.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.6.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.6.norm1.weight: weight_decay = 0.0
# ...
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.reduction.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.reduction.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.norm.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.norm.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.norm.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.norm.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm1.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm1.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.relative_position_bias_table: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.relative_position_bias_table: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.qkv.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.qkv.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.qkv.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.qkv.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.proj.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.proj.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.proj.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.proj.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm2.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm2.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc1.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc1.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc1.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc1.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc2.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc2.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc2.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc2.bias: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.norm3.weight: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.norm3.weight: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.norm3.bias: lr = 0.0001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.backbone.norm3.bias: weight_decay = 0.0
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.cls_head.fc_cls.weight: lr = 0.001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.cls_head.fc_cls.weight: weight_decay = 0.05
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.cls_head.fc_cls.bias: lr = 0.001
# 08/29 09:09:31 - mmengine - INFO - paramwise_options -- base.cls_head.fc_cls.bias: weight_decay = 0.05
# 08/29 09:09:32 - mmengine - INFO - load model from: https://download.openmmlab.com/mmaction/v1.0/recognition/swin/swin_base_patch4_window7_224.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmaction/v1.0/recognition/swin/swin_base_patch4_window7_224.pth
# 08/29 09:09:32 - mmengine - INFO - _IncompatibleKeys(missing_keys=['layers.0.blocks.0.attn.relative_position_index', 'layers.0.blocks.1.attn.relative_position_index', 'layers.1.blocks.0.attn.relative_position_index', 'layers.1.blocks.1.attn.relative_position_index', 'layers.2.blocks.0.attn.relative_position_index', 'layers.2.blocks.1.attn.relative_position_index', 'layers.2.blocks.2.attn.relative_position_index', 'layers.2.blocks.3.attn.relative_position_index', 'layers.2.blocks.4.attn.relative_position_index', 'layers.2.blocks.5.attn.relative_position_index', 'layers.2.blocks.6.attn.relative_position_index', 'layers.2.blocks.7.attn.relative_position_index', 'layers.2.blocks.8.attn.relative_position_index', 'layers.2.blocks.9.attn.relative_position_index', 'layers.2.blocks.10.attn.relative_position_index', 'layers.2.blocks.11.attn.relative_position_index', 'layers.2.blocks.12.attn.relative_position_index', 'layers.2.blocks.13.attn.relative_position_index', 'layers.2.blocks.14.attn.relative_position_index', 'layers.2.blocks.15.attn.relative_position_index', 'layers.2.blocks.16.attn.relative_position_index', 'layers.2.blocks.17.attn.relative_position_index', 'layers.3.blocks.0.attn.relative_position_index', 'layers.3.blocks.1.attn.relative_position_index'], unexpected_keys=['head.weight', 'head.bias'])
# Loads checkpoint by local backend from path: ./checkpoints/swin_base.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for cls_head.fc_cls.weight: copying a param with shape torch.Size([400, 1024]) from checkpoint, the shape in current model is torch.Size([45, 1024]).
# size mismatch for cls_head.fc_cls.bias: copying a param with shape torch.Size([400]) from checkpoint, the shape in current model is torch.Size([45]).
# 08/29 09:09:33 - mmengine - INFO - Load checkpoint from ./checkpoints/swin_base.pth
# 08/29 09:09:33 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/29 09:09:33 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/29 09:09:33 - mmengine - INFO - Checkpoints will be saved to /root/autodl-tmp/mmaction2/work_dirs/swin_base.
# 08/29 09:12:11 - mmengine - INFO - Exp name: swin_base_20230829_090925
# 08/29 09:12:11 - mmengine - INFO - Epoch(train)  [1][470/470]  base_lr: 4.5954e-04 lr: 4.5954e-05  eta: 2:45:41  time: 0.3299  data_time: 0.0116  memory: 12167  loss: 1.9026  top1_acc: 0.0000  top5_acc: 1.0000  loss_cls: 1.9026
# 08/29 09:12:11 - mmengine - INFO - Saving checkpoint at 1 epochs
# 08/29 09:12:35 - mmengine - INFO - Epoch(val) [1][118/118]    acc/top1: 0.6059  acc/top5: 0.9873  acc/mean1: 0.6104  data_time: 0.0178  time: 0.1770
# 08/29 09:12:37 - mmengine - INFO - The best checkpoint with 0.6059 acc/top1 at 1 epoch is saved to best_acc_top1_epoch_1.pth.
# 08/29 09:15:17 - mmengine - INFO - Exp name: swin_base_20230829_090925
# 08/29 09:15:17 - mmengine - INFO - Epoch(train)  [2][470/470]  base_lr: 8.1760e-04 lr: 8.1760e-05  eta: 2:42:12  time: 0.3255  data_time: 0.0086  memory: 12167  loss: 1.6135  top1_acc: 0.0000  top5_acc: 1.0000  loss_cls: 1.6135
# 08/29 09:15:17 - mmengine - INFO - Saving checkpoint at 2 epochs
# 08/29 09:15:40 - mmengine - INFO - Epoch(val) [2][118/118]    acc/top1: 0.6017  acc/top5: 0.9534  acc/mean1: 0.6302  data_time: 0.0059  time: 0.1654
# 08/29 09:16:00 - mmengine - INFO - Exp name: swin_base_20230829_090925
# 08/29 09:18:14 - mmengine - INFO - Exp name: swin_base_20230829_090925
# 08/29 09:18:14 - mmengine - INFO - Epoch(train)  [3][470/470]  base_lr: 9.8907e-04 lr: 9.8907e-05  eta: 2:38:46  time: 0.3248  data_time: 0.0077  memory: 12167  loss: 1.9307  top1_acc: 0.0000  top5_acc: 0.0000  loss_cls: 1.9307
# 08/29 09:18:14 - mmengine - INFO - Saving checkpoint at 3 epochs
# 08/29 09:18:38 - mmengine - INFO - Epoch(val) [3][118/118]    acc/top1: 0.7034  acc/top5: 0.9407  acc/mean1: 0.7026  data_time: 0.0061  time: 0.1655
# 08/29 09:18:38 - mmengine - INFO - The previous best checkpoint /root/autodl-tmp/mmaction2/work_dirs/swin_base/best_acc_top1_epoch_1.pth is removed
# 08/29 09:18:40 - mmengine - INFO - The best checkpoint with 0.7034 acc/top1 at 3 epoch is saved to best_acc_top1_epoch_3.pth.

# %%
# !python tools/analysis_tools/analyze_logs.py \
cal_train_time work_dirs/swin_base/20230810_013653/vis_data/scalars.json
# Out:
# -----Analyze train time of work_dirs/swin_base/20230810_013653/vis_data/scalars.json-----
# slowest epoch 20, average time is 0.3378
# fastest epoch 6, average time is 0.3321
# time std over epochs is 0.0013
# average iter time: 0.3349 s/iter

# %%
# !python tools/test.py ./configs/egocentric/swin_base.py \
   work_dirs/swin/base_best_acc_top1_epoch_62.pth  --dump work_dirs/swin_base_result.pkl
# Out:
# 08/29 20:32:21 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 325981038
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu118
#     OpenCV: 4.8.0
#     MMEngine: 0.8.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     deterministic: False
#     diff_rank_seed: False
#     seed: 325981038
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/29 20:32:21 - mmengine - INFO - Config:
# ann_file_test = 'data/video_fpha/fpha_val.txt'
# ann_file_train = 'data/video_fpha/fpha_train.txt'
# ann_file_val = 'data/video_fpha/fpha_val.txt'
# auto_scale_lr = dict(base_batch_size=64, enable=False)
# data_root = 'data/video_fpha/train'
# data_root_val = 'data/video_fpha/val'
# dataset_type = 'VideoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1, max_keep_ckpts=3, save_best='auto', type='CheckpointHook'),
#     logger=dict(ignore_last=True, interval=500, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     runtime_info=dict(type='RuntimeInfoHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffers=dict(type='SyncBuffersHook'),
#     timer=dict(type='IterTimerHook'))
# default_scope = 'mmaction'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# file_client_args = dict(io_backend='disk')
# launcher = 'none'
# load_from = 'work_dirs/swin/base_best_acc_top1_epoch_62.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)
# model = dict(
#     backbone=dict(
#         arch='base',
#         attn_drop_rate=0.0,
#         drop_path_rate=0.3,
#         drop_rate=0.0,
#         mlp_ratio=4.0,
#         patch_norm=True,
#         patch_size=(
#             2,
#             4,
#             4,
#         ),
#         pretrained=
#         'https://download.openmmlab.com/mmaction/v1.0/recognition/swin/swin_base_patch4_window7_224.pth',
#         pretrained2d=True,
#         qk_scale=None,
#         qkv_bias=True,
#         type='SwinTransformer3D',
#         window_size=(
#             8,
#             7,
#             7,
#         )),
#     cls_head=dict(
#         average_clips='prob',
#         dropout_ratio=0.5,
#         in_channels=1024,
#         num_classes=45,
#         spatial_type='avg',
#         type='I3DHead'),
#     data_preprocessor=dict(
#         format_shape='NCTHW',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='ActionDataPreprocessor'),
#     type='Recognizer3D')
# num_classes = 45
# optim_wrapper = dict(
#     constructor='SwinOptimWrapperConstructor',
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=0.001, type='AdamW', weight_decay=0.05),
#     paramwise_cfg=dict(
#         absolute_pos_embed=dict(decay_mult=0.0),
#         backbone=dict(lr_mult=0.1),
#         norm=dict(decay_mult=0.0),
#         relative_position_bias_table=dict(decay_mult=0.0)),
#     type='AmpOptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=2.5,
#         start_factor=0.1,
#         type='LinearLR'),
#     dict(
#         T_max=30,
#         begin=0,
#         by_epoch=True,
#         end=30,
#         eta_min=0,
#         type='CosineAnnealingLR'),
# ]
# randomness = dict(deterministic=False, diff_rank_seed=False, seed=None)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_val.txt',
#         data_prefix=dict(video='data/video_fpha/val'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=4,
#                 test_mode=True,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 224,
#             ), type='Resize'),
#             dict(crop_size=224, type='ThreeCrop'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         test_mode=True,
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = [
#     dict(type='AccMetric'),
#     dict(out_file_path='work_dirs/swin_base_result.pkl', type='DumpResults'),
# ]
# test_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(
#         clip_len=32,
#         frame_interval=2,
#         num_clips=4,
#         test_mode=True,
#         type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         224,
#     ), type='Resize'),
#     dict(crop_size=224, type='ThreeCrop'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# train_cfg = dict(
#     max_epochs=64, type='EpochBasedTrainLoop', val_begin=1, val_interval=1)
# train_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_train.txt',
#         data_prefix=dict(video='data/video_fpha/train'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=1,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 256,
#             ), type='Resize'),
#             dict(type='RandomResizedCrop'),
#             dict(keep_ratio=False, scale=(
#                 224,
#                 224,
#             ), type='Resize'),
#             dict(flip_ratio=0.5, type='Flip'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(clip_len=32, frame_interval=2, num_clips=1, type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         256,
#     ), type='Resize'),
#     dict(type='RandomResizedCrop'),
#     dict(keep_ratio=False, scale=(
#         224,
#         224,
#     ), type='Resize'),
#     dict(flip_ratio=0.5, type='Flip'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_val.txt',
#         data_prefix=dict(video='data/video_fpha/val'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=1,
#                 test_mode=True,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 256,
#             ), type='Resize'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         test_mode=True,
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(type='AccMetric')
# val_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(
#         clip_len=32,
#         frame_interval=2,
#         num_clips=1,
#         test_mode=True,
#         type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         256,
#     ), type='Resize'),
#     dict(crop_size=224, type='CenterCrop'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='ActionVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/swin_base'
#
# /root/miniconda3/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 08/29 20:32:25 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/29 20:32:25 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 08/29 20:32:26 - mmengine - WARNING - The prefix is not set in metric class DumpResults.
# Loads checkpoint by local backend from path: work_dirs/swin/base_best_acc_top1_epoch_62.pth
# 08/29 20:32:27 - mmengine - INFO - Load checkpoint from work_dirs/swin/base_best_acc_top1_epoch_62.pth
# 08/29 20:32:28 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/29 20:32:28 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/29 20:32:28 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/29 20:32:28 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/29 20:32:28 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/29 20:32:28 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/29 20:32:28 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/29 20:32:28 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/29 20:32:28 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/29 20:32:28 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/29 20:32:28 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/29 20:32:28 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/29 20:32:28 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/29 20:32:28 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/29 20:32:28 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/29 20:32:28 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/29 20:36:05 - mmengine - INFO - Results has been saved to work_dirs/swin_base_result.pkl.
# 08/29 20:36:05 - mmengine - INFO - Epoch(test) [236/236]    acc/top1: 0.9661  acc/top5: 1.0000  acc/mean1: 0.9719  data_time: 0.0150  time: 0.9252

# %% [markdown]
# ## confusion matrix

# %%
# !python tools/analysis_tools/confusion_matrix.py \
configs/egocentric/swin_base.py  work_dirs/swin/swin_base_result.pkl \
--label-file work_dirs/swin/action_annotation.txt \
--show --show-path ./work_dirs/swin/swin_base
# Out:
# Figure(1000x1000)
# The confusion matrix is saved at ./work_dirs/swin/swin_base.
