# %%
# %cd mmaction2
# Out:
# /root/autodl-tmp/mmaction2

# %% [markdown]
# ## swin_fpha_small

# %%
# %%writefile ./configs/egocentric/swin_fpha_small.py

#dataset
dataset_type = 'VideoDataset'
data_root = 'data/video_fpha/train'
data_root_val = 'data/video_fpha/val'
ann_file_train = 'data/video_fpha/fpha_train.txt'
ann_file_val = 'data/video_fpha/fpha_val.txt'
ann_file_test = 'data/video_fpha/fpha_val.txt'
auto_scale_lr = dict(base_batch_size=64, enable=False)
num_classes = 45

#hooks
default_hooks = dict(
    checkpoint=dict(
        interval=3, max_keep_ckpts=3, save_best='auto', type='CheckpointHook'),
    logger=dict(ignore_last=False, interval=100, type='LoggerHook'),
    param_scheduler=dict(type='ParamSchedulerHook'),
    runtime_info=dict(type='RuntimeInfoHook'),
    sampler_seed=dict(type='DistSamplerSeedHook'),
    sync_buffers=dict(type='SyncBuffersHook'),
    timer=dict(type='IterTimerHook'))
#enc
default_scope = 'mmaction'
env_cfg = dict(
    cudnn_benchmark=False,
    dist_cfg=dict(backend='nccl'),
    mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
file_client_args = dict(io_backend='disk')
launcher = 'none'
load_from = './checkpoints/swin_small.pth'
log_level = 'INFO'
log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)

# model
model = dict(
    backbone=dict(
        arch='small',
        attn_drop_rate=0.0,
        drop_path_rate=0.2,
        drop_rate=0.0,
        mlp_ratio=4.0,
        patch_norm=True,
        patch_size=(
            2,
            4,
            4,
        ),
        pretrained=
        'https://download.openmmlab.com/mmaction/v1.0/recognition/swin/swin_small_patch4_window7_224.pth',
        pretrained2d=True,
        qk_scale=None,
        qkv_bias=True,
        type='SwinTransformer3D',
        window_size=(
            8,
            7,
            7,
        )),
    cls_head=dict(
        average_clips='prob',
        dropout_ratio=0.5,
        in_channels=768,
        num_classes=45, # classes
        spatial_type='avg',
        type='I3DHead'),
    data_preprocessor=dict(
        format_shape='NCTHW',
        mean=[
            123.675,
            116.28,
            103.53,
        ],
        std=[
            58.395,
            57.12,
            57.375,
        ],
        type='ActionDataPreprocessor'),
    type='Recognizer3D')
#optim
optim_wrapper = dict(
    constructor='SwinOptimWrapperConstructor',
    optimizer=dict(
        betas=(
            0.9,
            0.999,
        ), lr=0.001, type='AdamW', weight_decay=0.02),
    paramwise_cfg=dict(
        absolute_pos_embed=dict(decay_mult=0.0),
        backbone=dict(lr_mult=0.1),
        norm=dict(decay_mult=0.0),
        relative_position_bias_table=dict(decay_mult=0.0)),
    type='AmpOptimWrapper')
#param
param_scheduler = [
    dict(
        begin=0,
        by_epoch=True,
        convert_to_iter_based=True,
        end=2.5,
        start_factor=0.1,
        type='LinearLR'),
    dict(
        T_max=30,
        begin=0,
        by_epoch=True,
        end=30,
        eta_min=0,
        type='CosineAnnealingLR'),
]
randomness = dict(deterministic=False, diff_rank_seed=False, seed=None)
resume = False
#test
test_cfg = dict(type='TestLoop')
test_dataloader = dict(
    batch_size=1,
    dataset=dict(
        ann_file='data/video_fpha/fpha_val.txt',
        data_prefix=dict(video='data/video_fpha/val'),
        pipeline=[
            dict(io_backend='disk', type='DecordInit'),
            dict(
                clip_len=32,
                frame_interval=2,
                num_clips=4,
                test_mode=True,
                type='SampleFrames'),
            dict(type='DecordDecode'),
            dict(scale=(
                -1,
                224,
            ), type='Resize'),
            dict(crop_size=224, type='ThreeCrop'),
            dict(input_format='NCTHW', type='FormatShape'),
            dict(type='PackActionInputs'),
        ],
        test_mode=True,
        type='VideoDataset'),
    num_workers=8,
    persistent_workers=True,
    sampler=dict(shuffle=False, type='DefaultSampler'))
test_evaluator = dict(type='AccMetric')
test_pipeline = [
    dict(io_backend='disk', type='DecordInit'),
    dict(
        clip_len=32,
        frame_interval=2,
        num_clips=4,
        test_mode=True,
        type='SampleFrames'),
    dict(type='DecordDecode'),
    dict(scale=(
        -1,
        224,
    ), type='Resize'),
    dict(crop_size=224, type='ThreeCrop'),
    dict(input_format='NCTHW', type='FormatShape'),
    dict(type='PackActionInputs'),
]
#train
train_cfg = dict( # max epochs
    max_epochs=32, type='EpochBasedTrainLoop', val_begin=1, val_interval=3)

train_dataloader = dict(
    batch_size=8,
    dataset=dict(
        ann_file='data/video_fpha/fpha_train.txt',
        data_prefix=dict(video='data/video_fpha/train'),
        pipeline=[
            dict(io_backend='disk', type='DecordInit'),
            dict(
                clip_len=32,
                frame_interval=2,
                num_clips=1,
                type='SampleFrames'),
            dict(type='DecordDecode'),
            dict(scale=(
                -1,
                256,
            ), type='Resize'),
            dict(type='RandomResizedCrop'),
            dict(keep_ratio=False, scale=(
                224,
                224,
            ), type='Resize'),
            dict(flip_ratio=0.5, type='Flip'),
            dict(input_format='NCTHW', type='FormatShape'),
            dict(type='PackActionInputs'),
        ],
        type='VideoDataset'),
    num_workers=8,
    persistent_workers=True,
    sampler=dict(shuffle=True, type='DefaultSampler'))
train_pipeline = [
    dict(io_backend='disk', type='DecordInit'),
    dict(clip_len=32, frame_interval=2, num_clips=1, type='SampleFrames'),
    dict(type='DecordDecode'),
    dict(scale=(
        -1,
        256,
    ), type='Resize'),
    dict(type='RandomResizedCrop'),
    dict(keep_ratio=False, scale=(
        224,
        224,
    ), type='Resize'),
    dict(flip_ratio=0.5, type='Flip'),
    dict(input_format='NCTHW', type='FormatShape'),
    dict(type='PackActionInputs'),
]
#val
val_cfg = dict(type='ValLoop')
val_dataloader = dict(
    batch_size=8,
    dataset=dict(
        ann_file='data/video_fpha/fpha_val.txt',
        data_prefix=dict(video='data/video_fpha/val'),
        pipeline=[
            dict(io_backend='disk', type='DecordInit'),
            dict(
                clip_len=32,
                frame_interval=2,
                num_clips=1,
                test_mode=True,
                type='SampleFrames'),
            dict(type='DecordDecode'),
            dict(scale=(
                -1,
                256,
            ), type='Resize'),
            dict(crop_size=224, type='CenterCrop'),
            dict(input_format='NCTHW', type='FormatShape'),
            dict(type='PackActionInputs'),
        ],
        test_mode=True,
        type='VideoDataset'),
    num_workers=8,
    persistent_workers=True,
    sampler=dict(shuffle=False, type='DefaultSampler'))
val_evaluator = dict(type='AccMetric')
val_pipeline = [
    dict(io_backend='disk', type='DecordInit'),
    dict(
        clip_len=32,
        frame_interval=2,
        num_clips=1,
        test_mode=True,
        type='SampleFrames'),
    dict(type='DecordDecode'),
    dict(scale=(
        -1,
        256,
    ), type='Resize'),
    dict(crop_size=224, type='CenterCrop'),
    dict(input_format='NCTHW', type='FormatShape'),
    dict(type='PackActionInputs'),
]
vis_backends = [
    dict(type='LocalVisBackend'),
]
visualizer = dict(
    type='ActionVisualizer', vis_backends=[
        dict(type='LocalVisBackend'),
    ])
work_dir = './work_dirs/swin_small'
# Out:
# Writing ./configs/egocentric/swin_fpha_small.py

# %%
# !python tools/train.py ./configs/egocentric/swin_fpha_small.py
# Out:
# 08/09 21:31:42 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: False
#     numpy_random_seed: 2062445580
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu118
#     OpenCV: 4.8.0
#     MMEngine: 0.8.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     deterministic: False
#     diff_rank_seed: False
#     seed: 2062445580
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/09 21:31:43 - mmengine - INFO - Config:
# ann_file_test = 'data/video_fpha/fpha_val.txt'
# ann_file_train = 'data/video_fpha/fpha_train.txt'
# ann_file_val = 'data/video_fpha/fpha_val.txt'
# auto_scale_lr = dict(base_batch_size=64, enable=False)
# data_root = 'data/video_fpha/train'
# data_root_val = 'data/video_fpha/val'
# dataset_type = 'VideoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3, max_keep_ckpts=3, save_best='auto', type='CheckpointHook'),
#     logger=dict(ignore_last=False, interval=100, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     runtime_info=dict(type='RuntimeInfoHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffers=dict(type='SyncBuffersHook'),
#     timer=dict(type='IterTimerHook'))
# default_scope = 'mmaction'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# file_client_args = dict(io_backend='disk')
# launcher = 'none'
# load_from = './checkpoints/swin_small.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)
# model = dict(
#     backbone=dict(
#         arch='small',
#         attn_drop_rate=0.0,
#         drop_path_rate=0.2,
#         drop_rate=0.0,
#         mlp_ratio=4.0,
#         patch_norm=True,
#         patch_size=(
#             2,
#             4,
#             4,
#         ),
#         pretrained=
#         'https://download.openmmlab.com/mmaction/v1.0/recognition/swin/swin_small_patch4_window7_224.pth',
#         pretrained2d=True,
#         qk_scale=None,
#         qkv_bias=True,
#         type='SwinTransformer3D',
#         window_size=(
#             8,
#             7,
#             7,
#         )),
#     cls_head=dict(
#         average_clips='prob',
#         dropout_ratio=0.5,
#         in_channels=768,
#         num_classes=45,
#         spatial_type='avg',
#         type='I3DHead'),
#     data_preprocessor=dict(
#         format_shape='NCTHW',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='ActionDataPreprocessor'),
#     type='Recognizer3D')
# num_classes = 45
# optim_wrapper = dict(
#     constructor='SwinOptimWrapperConstructor',
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=0.001, type='AdamW', weight_decay=0.02),
#     paramwise_cfg=dict(
#         absolute_pos_embed=dict(decay_mult=0.0),
#         backbone=dict(lr_mult=0.1),
#         norm=dict(decay_mult=0.0),
#         relative_position_bias_table=dict(decay_mult=0.0)),
#     type='AmpOptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=2.5,
#         start_factor=0.1,
#         type='LinearLR'),
#     dict(
#         T_max=30,
#         begin=0,
#         by_epoch=True,
#         end=30,
#         eta_min=0,
#         type='CosineAnnealingLR'),
# ]
# randomness = dict(deterministic=False, diff_rank_seed=False, seed=None)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_val.txt',
#         data_prefix=dict(video='data/video_fpha/val'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=4,
#                 test_mode=True,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 224,
#             ), type='Resize'),
#             dict(crop_size=224, type='ThreeCrop'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         test_mode=True,
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(type='AccMetric')
# test_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(
#         clip_len=32,
#         frame_interval=2,
#         num_clips=4,
#         test_mode=True,
#         type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         224,
#     ), type='Resize'),
#     dict(crop_size=224, type='ThreeCrop'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# train_cfg = dict(
#     max_epochs=32, type='EpochBasedTrainLoop', val_begin=1, val_interval=3)
# train_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_train.txt',
#         data_prefix=dict(video='data/video_fpha/train'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=1,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 256,
#             ), type='Resize'),
#             dict(type='RandomResizedCrop'),
#             dict(keep_ratio=False, scale=(
#                 224,
#                 224,
#             ), type='Resize'),
#             dict(flip_ratio=0.5, type='Flip'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(clip_len=32, frame_interval=2, num_clips=1, type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         256,
#     ), type='Resize'),
#     dict(type='RandomResizedCrop'),
#     dict(keep_ratio=False, scale=(
#         224,
#         224,
#     ), type='Resize'),
#     dict(flip_ratio=0.5, type='Flip'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_val.txt',
#         data_prefix=dict(video='data/video_fpha/val'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=1,
#                 test_mode=True,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 256,
#             ), type='Resize'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         test_mode=True,
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(type='AccMetric')
# val_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(
#         clip_len=32,
#         frame_interval=2,
#         num_clips=1,
#         test_mode=True,
#         type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         256,
#     ), type='Resize'),
#     dict(crop_size=224, type='CenterCrop'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='ActionVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/swin_small'
#
# /root/miniconda3/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 08/09 21:31:49 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/09 21:31:49 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.reduction.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.reduction.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.reduction.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.reduction.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.6.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.6.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.6.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.6.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.6.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.6.attn.relative_position_bias_table: weight_decay = 0.0
# ...
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.15.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.15.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.15.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.16.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.17.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.reduction.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.reduction.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.norm.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.norm.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.norm.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.norm.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.0.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm1.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm1.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.relative_position_bias_table: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.relative_position_bias_table: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.qkv.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.qkv.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.qkv.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.qkv.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.proj.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.proj.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.proj.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.attn.proj.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm2.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.norm2.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc1.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc1.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc1.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc1.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc2.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc2.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc2.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.layers.3.blocks.1.mlp.fc2.bias: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.norm3.weight: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.norm3.weight: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.norm3.bias: lr = 0.0001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.backbone.norm3.bias: weight_decay = 0.0
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.cls_head.fc_cls.weight: lr = 0.001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.cls_head.fc_cls.weight: weight_decay = 0.02
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.cls_head.fc_cls.bias: lr = 0.001
# 08/09 21:31:52 - mmengine - INFO - paramwise_options -- base.cls_head.fc_cls.bias: weight_decay = 0.02
# Traceback (most recent call last):
#   File "tools/train.py", line 135, in <module>
#     main()
#   File "tools/train.py", line 131, in main
#     runner.train()
#   File "/root/miniconda3/lib/python3.8/site-packages/mmengine/runner/runner.py", line 1708, in train
#     self.optim_wrapper = self.build_optim_wrapper(self.optim_wrapper)
#   File "/root/miniconda3/lib/python3.8/site-packages/mmengine/runner/runner.py", line 1097, in build_optim_wrapper
#     return build_optim_wrapper(self.model, optim_wrapper)
#   File "/root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/builder.py", line 201, in build_optim_wrapper
#     optim_wrapper = optim_wrapper_constructor(model)
#   File "/root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/default_constructor.py", line 306, in __call__
#     optim_wrapper = OPTIM_WRAPPERS.build(
#   File "/root/miniconda3/lib/python3.8/site-packages/mmengine/registry/registry.py", line 570, in build
#     return self.build_func(cfg, *args, **kwargs, registry=self)
#   File "/root/miniconda3/lib/python3.8/site-packages/mmengine/registry/build_functions.py", line 121, in build_from_cfg
#     obj = obj_cls(**args)  # type: ignore
#   File "/root/miniconda3/lib/python3.8/site-packages/mmengine/optim/optimizer/amp_optimizer_wrapper.py", line 76, in __init__
#     assert is_cuda_available() or is_npu_available() or is_mlu_available(
# AssertionError: ``AmpOptimizerWrapper`` is only available training on gpu, npu or mlu

# %% [markdown]
# ## analysis

# %%
# loss
# !python tools/analysis_tools/analyze_fpha.py \
plot_curve work_dirs/swin_fpha_small.json \
--keys loss \
--legend swin_loss \
--out analysis/swin_small_loss.pdf
# Out:
# plot curve of work_dirs/swin_fpha.json, metric is loss
# save curve to: analysis/swin_loss.pdf

# %%
# acc_top1 top5
# !python tools/analysis_tools/analyze_fpha.py \
plot_curve work_dirs/swin_fpha_small.json\
--keys top1_acc top5_acc \
--legend swin_top1_acc swin_top5_acc \
--out analysis/swin_top1_top5_small.pdf
# Out:
# plot curve of work_dirs/swin_fpha.json, metric is top1_acc
# plot curve of work_dirs/swin_fpha.json, metric is top5_acc
# save curve to: analysis/swin_top1_top5.pdf

# %%
# !python tools/analysis_tools/analyze_logs.py \
cal_train_time work_dirs/swin_fpha_small.json
# Out:
# -----Analyze train time of work_dirs/swin_fpha.json-----
# slowest epoch 123, average time is 0.5003
# fastest epoch 10, average time is 0.2648
# time std over epochs is 0.1034
# average iter time: 0.3429 s/iter
