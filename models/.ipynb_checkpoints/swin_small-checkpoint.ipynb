# %%
# %cd mmaction2
# Out:
# /root/autodl-tmp/mmaction2

# %% [markdown]
# ## swin_fpha

# %%
# %%writefile ./configs/egocentric/swin_fpha.py

#dataset
dataset_type = 'VideoDataset'
data_root = 'data/video_fpha/train'
data_root_val = 'data/video_fpha/val'
ann_file_train = 'data/video_fpha/fpha_train.txt'
ann_file_val = 'data/video_fpha/fpha_val.txt'
ann_file_test = 'data/video_fpha/fpha_val.txt'
auto_scale_lr = dict(base_batch_size=64, enable=False)
num_classes = 45

#set
default_hooks = dict(
    checkpoint=dict(
        interval=3, max_keep_ckpts=5, save_best='auto', type='CheckpointHook'),
    logger=dict(ignore_last=False, interval=100, type='LoggerHook'),
    param_scheduler=dict(type='ParamSchedulerHook'),
    runtime_info=dict(type='RuntimeInfoHook'),
    sampler_seed=dict(type='DistSamplerSeedHook'),
    sync_buffers=dict(type='SyncBuffersHook'),
    timer=dict(type='IterTimerHook'))
default_scope = 'mmaction'
env_cfg = dict(
    cudnn_benchmark=False,
    dist_cfg=dict(backend='nccl'),
    mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
file_client_args = dict(io_backend='disk')
launcher = 'none'
load_from = './checkpoints/swin_fpha.pth'
log_level = 'INFO'
log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)

#model
model = dict(
    backbone=dict(
        arch='tiny',
        attn_drop_rate=0.0,
        drop_path_rate=0.1,
        drop_rate=0.0,
        mlp_ratio=4.0,
        patch_norm=True,
        patch_size=(
            2,
            4,
            4,
        ),
        pretrained=
        'https://download.openmmlab.com/mmaction/v1.0/recognition/swin/swin_tiny_patch4_window7_224.pth',
        pretrained2d=True,
        qk_scale=None,
        qkv_bias=True,
        type='SwinTransformer3D',
        window_size=(
            8,
            7,
            7,
        )),
    cls_head=dict(
        average_clips='prob',
        dropout_ratio=0.5,
        in_channels=768,
        num_classes=45,#classes
        spatial_type='avg',
        type='I3DHead'),
    data_preprocessor=dict(
        format_shape='NCTHW',
        mean=[
            123.675,
            116.28,
            103.53,
        ],
        std=[
            58.395,
            57.12,
            57.375,
        ],
        type='ActionDataPreprocessor'),
    type='Recognizer3D')

#optim
optim_wrapper = dict(
    constructor='SwinOptimWrapperConstructor',
    optimizer=dict(
        betas=(
            0.9,
            0.999,
        ), lr=0.001, type='AdamW', weight_decay=0.02),
    paramwise_cfg=dict(
        absolute_pos_embed=dict(decay_mult=0.0),
        backbone=dict(lr_mult=0.1),
        norm=dict(decay_mult=0.0),
        relative_position_bias_table=dict(decay_mult=0.0)),
    type='AmpOptimWrapper')
#param
param_scheduler = [
    dict(
        begin=0,
        by_epoch=True,
        convert_to_iter_based=True,
        end=2.5,
        start_factor=0.1,
        type='LinearLR'),
    dict(
        T_max=30,
        begin=0,
        by_epoch=True,
        end=30,
        eta_min=0,
        type='CosineAnnealingLR'),
]
randomness = dict(deterministic=False, diff_rank_seed=False, seed=None)
resume = False

#test
test_cfg = dict(type='TestLoop')
test_dataloader = dict(
    batch_size=1,
    dataset=dict(
        ann_file='data/video_fpha/fpha_val.txt',
        data_prefix=dict(video='data/video_fpha/val'),
        pipeline=[
            dict(io_backend='disk', type='DecordInit'),
            dict(
                clip_len=32,
                frame_interval=2,
                num_clips=4,
                test_mode=True,
                type='SampleFrames'),
            dict(type='DecordDecode'),
            dict(scale=(
                -1,
                224,
            ), type='Resize'),
            dict(crop_size=224, type='ThreeCrop'),
            dict(input_format='NCTHW', type='FormatShape'),
            dict(type='PackActionInputs'),
        ],
        test_mode=True,
        type='VideoDataset'),
    num_workers=8,
    persistent_workers=True,
    sampler=dict(shuffle=False, type='DefaultSampler'))
test_evaluator = dict(type='AccMetric')
test_pipeline = [
    dict(io_backend='disk', type='DecordInit'),
    dict(
        clip_len=32,
        frame_interval=2,
        num_clips=4,
        test_mode=True,
        type='SampleFrames'),
    dict(type='DecordDecode'),
    dict(scale=(
        -1,
        224,
    ), type='Resize'),
    dict(crop_size=224, type='ThreeCrop'),
    dict(input_format='NCTHW', type='FormatShape'),
    dict(type='PackActionInputs'),
]
#train
train_cfg = dict(
    max_epochs=128, type='EpochBasedTrainLoop', val_begin=1, val_interval=3)
train_dataloader = dict(
    batch_size=4,
    dataset=dict(
        ann_file='data/video_fpha/fpha_train.txt',
        data_prefix=dict(video='data/video_fpha/train'),
        pipeline=[
            dict(io_backend='disk', type='DecordInit'),
            dict(
                clip_len=32,
                frame_interval=2,
                num_clips=1,
                type='SampleFrames'),
            dict(type='DecordDecode'),
            dict(scale=(
                -1,
                256,
            ), type='Resize'),
            dict(type='RandomResizedCrop'),
            dict(keep_ratio=False, scale=(
                224,
                224,
            ), type='Resize'),
            dict(flip_ratio=0.5, type='Flip'),
            dict(input_format='NCTHW', type='FormatShape'),
            dict(type='PackActionInputs'),
        ],
        type='VideoDataset'),
    num_workers=8,
    persistent_workers=True,
    sampler=dict(shuffle=True, type='DefaultSampler'))
train_pipeline = [
    dict(io_backend='disk', type='DecordInit'),
    dict(clip_len=32, frame_interval=2, num_clips=1, type='SampleFrames'),
    dict(type='DecordDecode'),
    dict(scale=(
        -1,
        256,
    ), type='Resize'),
    dict(type='RandomResizedCrop'),
    dict(keep_ratio=False, scale=(
        224,
        224,
    ), type='Resize'),
    dict(flip_ratio=0.5, type='Flip'),
    dict(input_format='NCTHW', type='FormatShape'),
    dict(type='PackActionInputs'),
]
#val
val_cfg = dict(type='ValLoop')
val_dataloader = dict(
    batch_size=4,
    dataset=dict(
        ann_file='data/video_fpha/fpha_val.txt',
        data_prefix=dict(video='data/video_fpha/val'),
        pipeline=[
            dict(io_backend='disk', type='DecordInit'),
            dict(
                clip_len=32,
                frame_interval=2,
                num_clips=1,
                test_mode=True,
                type='SampleFrames'),
            dict(type='DecordDecode'),
            dict(scale=(
                -1,
                256,
            ), type='Resize'),
            dict(crop_size=224, type='CenterCrop'),
            dict(input_format='NCTHW', type='FormatShape'),
            dict(type='PackActionInputs'),
        ],
        test_mode=True,
        type='VideoDataset'),
    num_workers=8,
    persistent_workers=True,
    sampler=dict(shuffle=False, type='DefaultSampler'))
val_evaluator = dict(type='AccMetric')
val_pipeline = [
    dict(io_backend='disk', type='DecordInit'),
    dict(
        clip_len=32,
        frame_interval=2,
        num_clips=1,
        test_mode=True,
        type='SampleFrames'),
    dict(type='DecordDecode'),
    dict(scale=(
        -1,
        256,
    ), type='Resize'),
    dict(crop_size=224, type='CenterCrop'),
    dict(input_format='NCTHW', type='FormatShape'),
    dict(type='PackActionInputs'),
]

vis_backends = [
    dict(type='LocalVisBackend'),
]
visualizer = dict(
    type='ActionVisualizer', vis_backends=[
        dict(type='LocalVisBackend'),
    ])

work_dir = './work_dirs/swin_fpha'
# Out:
# Overwriting ./configs/egocentric/swin_fpha.py

# %%
# !python tools/train.py ./configs/egocentric/swin_fpha.py
# Out:
# 08/06 06:46:51 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 835982176
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu118
#     OpenCV: 4.8.0
#     MMEngine: 0.8.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     deterministic: False
#     diff_rank_seed: False
#     seed: 835982176
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/06 06:46:52 - mmengine - INFO - Config:
# ann_file_test = 'data/video_fpha/fpha_val.txt'
# ann_file_train = 'data/video_fpha/fpha_train.txt'
# ann_file_val = 'data/video_fpha/fpha_val.txt'
# auto_scale_lr = dict(base_batch_size=64, enable=False)
# data_root = 'data/video_fpha/train'
# data_root_val = 'data/video_fpha/val'
# dataset_type = 'VideoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3, max_keep_ckpts=5, save_best='auto', type='CheckpointHook'),
#     logger=dict(ignore_last=False, interval=100, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     runtime_info=dict(type='RuntimeInfoHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffers=dict(type='SyncBuffersHook'),
#     timer=dict(type='IterTimerHook'))
# default_scope = 'mmaction'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# file_client_args = dict(io_backend='disk')
# launcher = 'none'
# load_from = './checkpoints/swin_fpha.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)
# model = dict(
#     backbone=dict(
#         arch='tiny',
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         drop_rate=0.0,
#         mlp_ratio=4.0,
#         patch_norm=True,
#         patch_size=(
#             2,
#             4,
#             4,
#         ),
#         pretrained=
#         'https://download.openmmlab.com/mmaction/v1.0/recognition/swin/swin_tiny_patch4_window7_224.pth',
#         pretrained2d=True,
#         qk_scale=None,
#         qkv_bias=True,
#         type='SwinTransformer3D',
#         window_size=(
#             8,
#             7,
#             7,
#         )),
#     cls_head=dict(
#         average_clips='prob',
#         dropout_ratio=0.5,
#         in_channels=768,
#         num_classes=45,
#         spatial_type='avg',
#         type='I3DHead'),
#     data_preprocessor=dict(
#         format_shape='NCTHW',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='ActionDataPreprocessor'),
#     type='Recognizer3D')
# optim_wrapper = dict(
#     constructor='SwinOptimWrapperConstructor',
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=0.001, type='AdamW', weight_decay=0.02),
#     paramwise_cfg=dict(
#         absolute_pos_embed=dict(decay_mult=0.0),
#         backbone=dict(lr_mult=0.1),
#         norm=dict(decay_mult=0.0),
#         relative_position_bias_table=dict(decay_mult=0.0)),
#     type='AmpOptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=2.5,
#         start_factor=0.1,
#         type='LinearLR'),
#     dict(
#         T_max=30,
#         begin=0,
#         by_epoch=True,
#         end=30,
#         eta_min=0,
#         type='CosineAnnealingLR'),
# ]
# randomness = dict(deterministic=False, diff_rank_seed=False, seed=None)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_val.txt',
#         data_prefix=dict(video='data/video_fpha/val'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=4,
#                 test_mode=True,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 224,
#             ), type='Resize'),
#             dict(crop_size=224, type='ThreeCrop'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         test_mode=True,
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(type='AccMetric')
# test_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(
#         clip_len=32,
#         frame_interval=2,
#         num_clips=4,
#         test_mode=True,
#         type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         224,
#     ), type='Resize'),
#     dict(crop_size=224, type='ThreeCrop'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# train_cfg = dict(
#     max_epochs=128, type='EpochBasedTrainLoop', val_begin=1, val_interval=3)
# train_dataloader = dict(
#     batch_size=4,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_train.txt',
#         data_prefix=dict(video='data/video_fpha/train'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=1,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 256,
#             ), type='Resize'),
#             dict(type='RandomResizedCrop'),
#             dict(keep_ratio=False, scale=(
#                 224,
#                 224,
#             ), type='Resize'),
#             dict(flip_ratio=0.5, type='Flip'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(clip_len=32, frame_interval=2, num_clips=1, type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         256,
#     ), type='Resize'),
#     dict(type='RandomResizedCrop'),
#     dict(keep_ratio=False, scale=(
#         224,
#         224,
#     ), type='Resize'),
#     dict(flip_ratio=0.5, type='Flip'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=4,
#     dataset=dict(
#         ann_file='data/video_fpha/fpha_val.txt',
#         data_prefix=dict(video='data/video_fpha/val'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=2,
#                 num_clips=1,
#                 test_mode=True,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 256,
#             ), type='Resize'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         test_mode=True,
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(type='AccMetric')
# val_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(
#         clip_len=32,
#         frame_interval=2,
#         num_clips=1,
#         test_mode=True,
#         type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         256,
#     ), type='Resize'),
#     dict(crop_size=224, type='CenterCrop'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='ActionVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/swin_fpha'
#
# /root/miniconda3/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 08/06 06:46:56 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/06 06:46:56 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.proj.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.patch_embed.norm.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm1.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.relative_position_bias_table: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.relative_position_bias_table: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.qkv.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.attn.proj.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.norm2.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc1.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.0.mlp.fc2.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm1.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.relative_position_bias_table: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.relative_position_bias_table: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.qkv.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.attn.proj.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.norm2.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc1.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.blocks.1.mlp.fc2.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.reduction.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.reduction.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.0.downsample.norm.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm1.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.relative_position_bias_table: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.relative_position_bias_table: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.qkv.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.attn.proj.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.norm2.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc1.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.0.mlp.fc2.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm1.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.relative_position_bias_table: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.relative_position_bias_table: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.qkv.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.attn.proj.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.norm2.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc1.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.blocks.1.mlp.fc2.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.reduction.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.reduction.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.1.downsample.norm.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm1.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.relative_position_bias_table: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.relative_position_bias_table: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.qkv.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.attn.proj.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.norm2.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc1.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.0.mlp.fc2.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm1.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.relative_position_bias_table: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.relative_position_bias_table: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.qkv.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.attn.proj.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.norm2.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc1.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.1.mlp.fc2.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm1.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.relative_position_bias_table: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.relative_position_bias_table: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.qkv.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.attn.proj.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.norm2.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc1.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.2.mlp.fc2.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm1.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.relative_position_bias_table: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.relative_position_bias_table: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.qkv.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.attn.proj.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.norm2.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc1.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.3.mlp.fc2.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm1.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.relative_position_bias_table: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.relative_position_bias_table: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.qkv.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.attn.proj.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.norm2.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc1.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.4.mlp.fc2.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm1.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.relative_position_bias_table: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.relative_position_bias_table: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.qkv.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.attn.proj.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.weight: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.norm2.bias: weight_decay = 0.0
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc1.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.weight: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.bias: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.blocks.5.mlp.fc2.bias: weight_decay = 0.02
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.reduction.weight: lr = 0.0001
# 08/06 06:46:56 - mmengine - INFO - paramwise_options -- base.backbone.layers.2.downsample.reduction.weight: weight_decay = 0.02
# ...
# 08/06 08:24:39 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:24:39 - mmengine - INFO - Epoch(train)  [86][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:45:15  time: 0.4918  data_time: 0.0152  memory: 10713  loss: 0.1689  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1689
# 08/06 08:25:24 - mmengine - INFO - Epoch(train)  [87][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:44:56  time: 0.3102  data_time: 0.0116  memory: 10713  loss: 0.2163  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2163
# 08/06 08:25:52 - mmengine - INFO - Epoch(train)  [87][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:44:28  time: 0.2745  data_time: 0.0142  memory: 10713  loss: 0.2667  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2667
# 08/06 08:26:01 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:26:01 - mmengine - INFO - Epoch(train)  [87][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:44:18  time: 0.2668  data_time: 0.0095  memory: 10713  loss: 0.3097  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.3097
# 08/06 08:26:01 - mmengine - INFO - Saving checkpoint at 87 epochs
# 08/06 08:26:12 - mmengine - INFO - Epoch(val) [87][59/59]    acc/top1: 0.9661  acc/top5: 1.0000  acc/mean1: 0.9708  data_time: 0.0207  time: 0.1551
# 08/06 08:26:41 - mmengine - INFO - Epoch(train)  [88][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:43:51  time: 0.2784  data_time: 0.0165  memory: 10713  loss: 0.1855  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1855
# 08/06 08:27:09 - mmengine - INFO - Epoch(train)  [88][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:43:24  time: 0.2913  data_time: 0.0193  memory: 10713  loss: 0.4413  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.4413
# 08/06 08:27:24 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:27:24 - mmengine - INFO - Epoch(train)  [88][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:43:17  time: 0.4991  data_time: 0.0152  memory: 10713  loss: 0.1722  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1722
# 08/06 08:28:14 - mmengine - INFO - Epoch(train)  [89][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:42:59  time: 0.4906  data_time: 0.0074  memory: 10713  loss: 0.3311  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.3311
# 08/06 08:29:03 - mmengine - INFO - Epoch(train)  [89][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:42:41  time: 0.5002  data_time: 0.0171  memory: 10713  loss: 0.1223  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1223
# 08/06 08:29:20 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:29:20 - mmengine - INFO - Epoch(train)  [89][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:42:34  time: 0.4978  data_time: 0.0176  memory: 10713  loss: 0.2497  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2497
# 08/06 08:30:03 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:30:11 - mmengine - INFO - Epoch(train)  [90][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:42:16  time: 0.5008  data_time: 0.0157  memory: 10713  loss: 0.2696  top1_acc: 0.7500  top5_acc: 1.0000  loss_cls: 0.2696
# 08/06 08:31:01 - mmengine - INFO - Epoch(train)  [90][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:41:58  time: 0.5006  data_time: 0.0148  memory: 10713  loss: 0.3333  top1_acc: 0.7500  top5_acc: 0.7500  loss_cls: 0.3333
# 08/06 08:31:18 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:31:18 - mmengine - INFO - Epoch(train)  [90][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:41:51  time: 0.4918  data_time: 0.0123  memory: 10713  loss: 0.3554  top1_acc: 0.6667  top5_acc: 1.0000  loss_cls: 0.3554
# 08/06 08:31:18 - mmengine - INFO - Saving checkpoint at 90 epochs
# 08/06 08:31:36 - mmengine - INFO - Epoch(val) [90][59/59]    acc/top1: 0.9703  acc/top5: 1.0000  acc/mean1: 0.9740  data_time: 0.0127  time: 0.2690
# 08/06 08:32:25 - mmengine - INFO - Epoch(train)  [91][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:41:32  time: 0.5059  data_time: 0.0167  memory: 10713  loss: 0.2710  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2710
# 08/06 08:33:12 - mmengine - INFO - Epoch(train)  [91][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:41:11  time: 0.3962  data_time: 0.0181  memory: 10713  loss: 0.3096  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.3096
# 08/06 08:33:29 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:33:29 - mmengine - INFO - Epoch(train)  [91][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:41:04  time: 0.4941  data_time: 0.0139  memory: 10713  loss: 0.2354  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2354
# 08/06 08:34:20 - mmengine - INFO - Epoch(train)  [92][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:40:45  time: 0.4870  data_time: 0.0171  memory: 10713  loss: 0.1444  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1444
# 08/06 08:35:10 - mmengine - INFO - Epoch(train)  [92][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:40:25  time: 0.5029  data_time: 0.0147  memory: 10713  loss: 0.2094  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2094
# 08/06 08:45:28 - mmengine - INFO - Epoch(train)  [97][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:36:09  time: 0.5007  data_time: 0.0152  memory: 10713  loss: 0.1752  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1752
# 08/06 08:45:45 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:45:45 - mmengine - INFO - Epoch(train)  [97][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:36:01  time: 0.4910  data_time: 0.0141  memory: 10713  loss: 0.1934  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1934
# 08/06 08:46:35 - mmengine - INFO - Epoch(train)  [98][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:35:37  time: 0.4979  data_time: 0.0142  memory: 10713  loss: 0.1382  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1382
# 08/06 08:47:24 - mmengine - INFO - Epoch(train)  [98][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:35:13  time: 0.4871  data_time: 0.0152  memory: 10713  loss: 0.1891  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1891
# 08/06 08:47:27 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:47:42 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:47:42 - mmengine - INFO - Epoch(train)  [98][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:35:05  time: 0.4887  data_time: 0.0122  memory: 10713  loss: 0.2375  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2375
# 08/06 08:48:32 - mmengine - INFO - Epoch(train)  [99][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:34:41  time: 0.4888  data_time: 0.0154  memory: 10713  loss: 0.3176  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.3176
# 08/06 08:49:22 - mmengine - INFO - Epoch(train)  [99][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:34:17  time: 0.5006  data_time: 0.0138  memory: 10713  loss: 0.1763  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1763
# 08/06 08:49:39 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:49:39 - mmengine - INFO - Epoch(train)  [99][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:34:09  time: 0.4806  data_time: 0.0153  memory: 10713  loss: 0.2136  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2136
# 08/06 08:49:39 - mmengine - INFO - Saving checkpoint at 99 epochs
# 08/06 08:49:57 - mmengine - INFO - Epoch(val) [99][59/59]    acc/top1: 0.9703  acc/top5: 1.0000  acc/mean1: 0.9740  data_time: 0.0169  time: 0.2759
# 08/06 08:50:46 - mmengine - INFO - Epoch(train) [100][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:33:44  time: 0.4287  data_time: 0.0147  memory: 10713  loss: 0.1371  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1371
# 08/06 08:51:35 - mmengine - INFO - Epoch(train) [100][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:33:19  time: 0.5020  data_time: 0.0145  memory: 10713  loss: 0.1689  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1689
# 08/06 08:51:52 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:51:52 - mmengine - INFO - Epoch(train) [100][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:33:10  time: 0.4916  data_time: 0.0151  memory: 10713  loss: 0.2843  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2843
# 08/06 08:52:42 - mmengine - INFO - Epoch(train) [101][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:32:46  time: 0.4994  data_time: 0.0130  memory: 10713  loss: 0.0992  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0992
# 08/06 08:53:32 - mmengine - INFO - Epoch(train) [101][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:32:20  time: 0.5034  data_time: 0.0166  memory: 10713  loss: 0.4113  top1_acc: 0.7500  top5_acc: 0.7500  loss_cls: 0.4113
# 08/06 08:53:49 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 08:53:49 - mmengine - INFO - Epoch(train) [101][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:32:12  time: 0.4964  data_time: 0.0157  memory: 10713  loss: 0.3290  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.3290
# 08/06 09:08:00 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 09:08:00 - mmengine - INFO - Epoch(train) [108][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:24:49  time: 0.4914  data_time: 0.0150  memory: 10713  loss: 0.3329  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.3329
# 08/06 09:08:00 - mmengine - INFO - Saving checkpoint at 108 epochs
# 08/06 09:08:18 - mmengine - INFO - Epoch(val) [108][59/59]    acc/top1: 0.9703  acc/top5: 1.0000  acc/mean1: 0.9740  data_time: 0.0172  time: 0.2749
# 08/06 09:09:05 - mmengine - INFO - Epoch(train) [109][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:24:20  time: 0.5026  data_time: 0.0154  memory: 10713  loss: 0.2591  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2591
# 08/06 09:09:54 - mmengine - INFO - Epoch(train) [109][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:23:51  time: 0.5003  data_time: 0.0143  memory: 10713  loss: 0.0592  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0592
# 08/06 09:10:11 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 09:10:11 - mmengine - INFO - Epoch(train) [109][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:23:41  time: 0.4932  data_time: 0.0145  memory: 10713  loss: 0.1771  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1771
# 08/06 09:11:02 - mmengine - INFO - Epoch(train) [110][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:23:12  time: 0.4862  data_time: 0.0139  memory: 10713  loss: 0.2265  top1_acc: 0.7500  top5_acc: 1.0000  loss_cls: 0.2265
# 08/06 09:11:52 - mmengine - INFO - Epoch(train) [110][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:22:44  time: 0.5016  data_time: 0.0157  memory: 10713  loss: 0.3824  top1_acc: 0.7500  top5_acc: 1.0000  loss_cls: 0.3824
# 08/06 09:37:26 - mmengine - INFO - Epoch(train) [123][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:07:22  time: 0.4956  data_time: 0.0110  memory: 10713  loss: 0.1028  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1028
# 08/06 09:38:14 - mmengine - INFO - Epoch(train) [123][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:06:49  time: 0.5028  data_time: 0.0149  memory: 10713  loss: 0.1974  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1974
# 08/06 09:38:32 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 09:38:32 - mmengine - INFO - Epoch(train) [123][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:06:37  time: 0.4977  data_time: 0.0157  memory: 10713  loss: 0.3139  top1_acc: 0.6667  top5_acc: 1.0000  loss_cls: 0.3139
# 08/06 09:38:32 - mmengine - INFO - Saving checkpoint at 123 epochs
# 08/06 09:38:50 - mmengine - INFO - Epoch(val) [123][59/59]    acc/top1: 0.9703  acc/top5: 1.0000  acc/mean1: 0.9740  data_time: 0.0166  time: 0.2766
# 08/06 09:39:37 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 09:39:39 - mmengine - INFO - Epoch(train) [124][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:06:04  time: 0.5001  data_time: 0.0154  memory: 10713  loss: 0.2449  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2449
# 08/06 09:40:29 - mmengine - INFO - Epoch(train) [124][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:05:31  time: 0.5011  data_time: 0.0143  memory: 10713  loss: 0.1438  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1438
# 08/06 09:40:46 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 09:40:46 - mmengine - INFO - Epoch(train) [124][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:05:19  time: 0.4910  data_time: 0.0119  memory: 10713  loss: 0.2666  top1_acc: 0.6667  top5_acc: 0.6667  loss_cls: 0.2666
# 08/06 09:41:36 - mmengine - INFO - Epoch(train) [125][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:04:45  time: 0.4809  data_time: 0.0095  memory: 10713  loss: 0.1896  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1896
# 08/06 09:42:26 - mmengine - INFO - Epoch(train) [125][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:04:12  time: 0.5031  data_time: 0.0151  memory: 10713  loss: 0.2357  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2357
# 08/06 09:42:42 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 09:42:42 - mmengine - INFO - Epoch(train) [125][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:04:00  time: 0.4316  data_time: 0.0095  memory: 10713  loss: 0.1729  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1729
# 08/06 09:43:32 - mmengine - INFO - Epoch(train) [126][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:03:26  time: 0.4982  data_time: 0.0150  memory: 10713  loss: 0.1049  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1049
# 08/06 09:44:21 - mmengine - INFO - Epoch(train) [126][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:02:52  time: 0.4906  data_time: 0.0083  memory: 10713  loss: 0.2158  top1_acc: 0.7500  top5_acc: 1.0000  loss_cls: 0.2158
# 08/06 09:44:38 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 09:44:38 - mmengine - INFO - Epoch(train) [126][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:02:40  time: 0.4881  data_time: 0.0097  memory: 10713  loss: 0.2037  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2037
# 08/06 09:44:38 - mmengine - INFO - Saving checkpoint at 126 epochs
# 08/06 09:44:55 - mmengine - INFO - Epoch(val) [126][59/59]    acc/top1: 0.9703  acc/top5: 1.0000  acc/mean1: 0.9740  data_time: 0.0171  time: 0.2769
# 08/06 09:45:45 - mmengine - INFO - Epoch(train) [127][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:02:06  time: 0.4971  data_time: 0.0126  memory: 10713  loss: 0.2280  top1_acc: 0.7500  top5_acc: 1.0000  loss_cls: 0.2280
# 08/06 09:46:35 - mmengine - INFO - Epoch(train) [127][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:01:32  time: 0.4945  data_time: 0.0099  memory: 10713  loss: 0.2761  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2761
# 08/06 09:46:52 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 09:46:52 - mmengine - INFO - Epoch(train) [127][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:01:20  time: 0.4882  data_time: 0.0101  memory: 10713  loss: 0.2023  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2023
# 08/06 09:47:41 - mmengine - INFO - Epoch(train) [128][100/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:00:46  time: 0.4953  data_time: 0.0103  memory: 10713  loss: 0.3711  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.3711
# 08/06 09:48:08 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 09:48:31 - mmengine - INFO - Epoch(train) [128][200/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:00:12  time: 0.5013  data_time: 0.0144  memory: 10713  loss: 0.2494  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2494
# 08/06 09:48:48 - mmengine - INFO - Exp name: swin_fpha_20230806_064650
# 08/06 09:48:48 - mmengine - INFO - Epoch(train) [128][235/235]  base_lr: 2.7391e-06 lr: 2.7391e-07  eta: 0:00:00  time: 0.4885  data_time: 0.0129  memory: 10713  loss: 0.2788  top1_acc: 0.6667  top5_acc: 0.6667  loss_cls: 0.2788
# 08/06 09:48:48 - mmengine - INFO - Saving checkpoint at 128 epochs

# %% [markdown]
# ## analysis

# %%
# loss
# !python tools/analysis_tools/analyze_fpha.py \
plot_curve work_dirs/swin_fpha.json \
--keys loss \
--legend swin_loss \
--out analysis/swin_loss.pdf
# Out:
# plot curve of work_dirs/swin_fpha.json, metric is loss
# save curve to: analysis/swin_loss.pdf

# %%
# acc_top1 top5
# !python tools/analysis_tools/analyze_fpha.py \
plot_curve work_dirs/swin_fpha.json\
--keys top1_acc top5_acc \
--legend swin_top1_acc swin_top5_acc \
--out analysis/swin_top1_top5.pdf
# Out:
# plot curve of work_dirs/swin_fpha.json, metric is top1_acc
# plot curve of work_dirs/swin_fpha.json, metric is top5_acc
# save curve to: analysis/swin_top1_top5.pdf

# %%
# !python tools/analysis_tools/analyze_logs.py \
cal_train_time work_dirs/swin_fpha.json
# Out:
# -----Analyze train time of work_dirs/swin_fpha.json-----
# slowest epoch 123, average time is 0.5003
# fastest epoch 10, average time is 0.2648
# time std over epochs is 0.1034
# average iter time: 0.3429 s/iter
